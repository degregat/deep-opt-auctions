# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('dp_exp_1.csv')
sns.set(rc={'figure.figsize':(10,10)})

# %%
iter4k_smalleps = data.query('Iter==4000').query('Epsilon<1000').query('Clip<100 and Noise < 1.5')

# %%
sns.scatterplot(x='Noise', y='Clip', hue='Epsilon', size='Revenue', sizes=(100,500), data=iter4k_smalleps)

# %%
sns.scatterplot(x='Noise', y='Clip', hue='Revenue', size='Regret', sizes=(100,500), data=iter4k_smalleps)

# %%
sns.scatterplot(x='Noise', y='Clip', hue='Revenue', size='Epsilon', sizes=(100,500), data=iter4k_smalleps)

# %%
sns.scatterplot(x='Noise', y='Clip', hue='Epsilon', size='Regret', sizes=(100,500), data=iter4k_smalleps)
